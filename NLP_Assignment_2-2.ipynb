# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/Healthcare.csv")  # adjust name if needed
df.head(), df.shape
# Out:
# (   Patient_ID  Age  Gender                                           Symptoms  \
#  0           1   29    Male              fever, back pain, shortness of breath
#  1           2   76  Female                   insomnia, back pain, weight loss
#  2           3   78    Male                    sore throat, vomiting, diarrhea
#  3           4   58   Other  blurred vision, depression, weight loss, muscl...
#  4           5   55  Female                    swelling, appetite loss, nausea
#
#     Symptom_Count           Disease
#  0              3           Allergy
#  1              3  Thyroid Disorder
#  2              3         Influenza
#  3              4            Stroke
#  4              3     Heart Disease  ,
#  (25000, 6))

# %%
def parse_symptoms(sym_str):
    return [s.strip().lower() for s in sym_str.split(",")]

df["Symptom_List"] = df["Symptoms"].astype(str).apply(parse_symptoms)
df[["Disease", "Symptom_List"]].head()
# Out:
#             Disease                                       Symptom_List
# 0           Allergy            [fever, back pain, shortness of breath]
# 1  Thyroid Disorder                 [insomnia, back pain, weight loss]
# 2         Influenza                  [sore throat, vomiting, diarrhea]
# 3            Stroke  [blurred vision, depression, weight loss, musc...
# 4     Heart Disease                  [swelling, appetite loss, nausea]

# %%
symptoms = sorted({s for lst in df["Symptom_List"] for s in lst})
diseases = sorted(df["Disease"].unique())

len(symptoms), len(diseases)
# Out:
# (28, 30)

# %%
M = pd.DataFrame(0, index=diseases, columns=symptoms)

for disease, lst in zip(df["Disease"], df["Symptom_List"]):
    for s in lst:
        M.loc[disease, s] += 1

M.shape
# Out:
# (30, 28)

# %%
M_norm = M.div(M.sum(axis=1), axis=0).fillna(0)
M_norm.shape
# Out:
# (30, 28)

# %%
from sklearn.cluster import KMeans

k = 6
km = KMeans(n_clusters=k, random_state=42, n_init="auto")
labels = km.fit_predict(M_norm)

cluster_sizes = pd.Series(labels).value_counts().sort_index()
cluster_sizes
# Out:
# 0    9
# 1    6
# 2    1
# 3    1
# 4    8
# 5    5
# Name: count, dtype: int64

# %%
from sklearn.metrics.pairwise import euclidean_distances

centroids = km.cluster_centers_

singleton_clusters = cluster_sizes[cluster_sizes == 1].index.tolist()
non_singleton_clusters = cluster_sizes[cluster_sizes > 1].index.tolist()

labels_merged = labels.copy()

for sc in singleton_clusters:
    outlier_disease = M_norm.index[labels == sc][0]
    outlier_vec = M_norm.loc[outlier_disease].values.reshape(1, -1)

    dists = euclidean_distances(outlier_vec, centroids)[0]
    target = min(non_singleton_clusters, key=lambda c: dists[c])

    print(f"Merging {outlier_disease} from cluster {sc} → cluster {target}")
    labels_merged[M_norm.index.get_loc(outlier_disease)] = target
# Out:
# Merging Arthritis from cluster 2 → cluster 1
# Merging Hypertension from cluster 3 → cluster 4

# %%
unique_clusters = sorted(np.unique(labels_merged))
cluster_remap = {old:i for i, old in enumerate(unique_clusters)}

labels_final = np.array([cluster_remap[x] for x in labels_merged])

pd.Series(labels_final).value_counts().sort_index()
# Out:
# 0    9
# 1    7
# 2    9
# 3    5
# Name: count, dtype: int64

# %%
disease_to_group = {
    disease: group
    for disease, group in zip(M_norm.index, labels_final)
}

df["Disease_Group"] = df["Disease"].map(disease_to_group)
df["Disease_Group"].value_counts()
# Out:
# Disease_Group
# 2    7462
# 0    7397
# 1    6015
# 3    4126
# Name: count, dtype: int64

# %%
df["Symptom_Text"] = df["Symptom_List"].apply(
    lambda lst: " ".join(s.replace(" ", "_") for s in lst)
)

# %%
symptom_index = {s:i for i,s in enumerate(symptoms)}

def multi_hot(lst):
    v = np.zeros(len(symptoms), dtype=np.int32)
    for s in lst:
        v[symptom_index[s]] = 1
    return v

df["Symptom_MultiHot"] = df["Symptom_List"].apply(multi_hot)

# %%
df["Symptom_Seq"] = df["Symptom_List"].apply(
    lambda lst: [symptom_index[s] for s in lst]
)

max_len = df["Symptom_Seq"].apply(len).max()
max_len
# Out:
# 7

# %%
from sklearn.model_selection import train_test_split

y = df["Disease_Group"]

train_idx, temp_idx = train_test_split(
    df.index, test_size=0.30, random_state=42, stratify=y
)
val_idx, test_idx = train_test_split(
    temp_idx, test_size=0.50, random_state=42, stratify=y.loc[temp_idx]
)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(
    ngram_range=(1, 2),
    min_df=2,
    max_df=0.95
)

X_tfidf = tfidf.fit_transform(df["Symptom_Text"])
y = df["Disease_Group"]

# %%
X_train = X_tfidf[train_idx]
X_val   = X_tfidf[val_idx]
X_test  = X_tfidf[test_idx]

y_train = y.loc[train_idx]
y_val   = y.loc[val_idx]
y_test  = y.loc[test_idx]

# %%
from sklearn.svm import LinearSVC

svm = LinearSVC(C=1.0, max_iter=5000)
svm.fit(X_train, y_train)
# Out:
# LinearSVC(max_iter=5000)

# %%
from sklearn.metrics import accuracy_score

val_pred = svm.predict(X_val)
test_pred = svm.predict(X_test)

val_acc = accuracy_score(y_val, val_pred)
test_acc = accuracy_score(y_test, test_pred)

print("SVM (TF-IDF) Validation Accuracy:", val_acc)
print("SVM (TF-IDF) Test Accuracy:", test_acc)
# Out:
# SVM (TF-IDF) Validation Accuracy: 0.2850666666666667
# SVM (TF-IDF) Test Accuracy: 0.2872

# %%
results = {}

results["SVM (TF-IDF)"] = {
    "val_acc": val_acc,
    "test_acc": test_acc
}

results
# Out:
# {'SVM (TF-IDF)': {'val_acc': 0.2850666666666667, 'test_acc': 0.2872}}

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical

# Features
X_mh = np.stack(df["Symptom_MultiHot"].values)

# Labels
y_cat = to_categorical(df["Disease_Group"], num_classes=4)

X_train = X_mh[train_idx]
X_val   = X_mh[val_idx]
X_test  = X_mh[test_idx]

y_train = y_cat[train_idx]
y_val   = y_cat[val_idx]
y_test  = y_cat[test_idx]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

ffnn = Sequential([
    Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
    Dropout(0.3),
    Dense(32, activation="relu"),
    Dense(4, activation="softmax")
])

ffnn.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

ffnn.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         1,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,068 (15.89 KB)
#  Trainable params: 4,068 (15.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = ffnn.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=128,
    verbose=1
)
# Out:
# Epoch 1/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━
50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3534 - loss: 1.3313 - val_accuracy: 0.3056 - val_loss: 1.3728
# Epoch 33/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3541 - loss: 1.3302 - val_accuracy: 0.3075 - val_loss: 1.3735
# Epoch 34/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3519 - loss: 1.3295 - val_accuracy: 0.3077 - val_loss: 1.3757
# Epoch 35/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3533 - loss: 1.3290 - val_accuracy: 0.3040 - val_loss: 1.3746
# Epoch 36/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.3535 - loss: 1.3251 - val_accuracy: 0.3005 - val_loss: 1.3757
# Epoch 37/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.3469 - loss: 1.3313 - val_accuracy: 0.3029 - val_loss: 1.3778
# Epoch 38/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3486 - loss: 1.3285 - val_accuracy: 0.3003 - val_loss: 1.3754
# Epoch 39/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3529 - loss: 1.3270 - val_accuracy: 0.3019 - val_loss: 1.3757
# Epoch 40/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3587 - loss: 1.3267 - val_accuracy: 0.3037 - val_loss: 1.3758
# Epoch 41/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3519 - loss: 1.3255 - val_accuracy: 0.3037 - val_loss: 1.3774
# Epoch 42/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3554 - loss: 1.3272 - val_accuracy: 0.3061 - val_loss: 1.3775
# Epoch 43/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3574 - loss: 1.3265 - val_accuracy: 0.3067 - val_loss: 1.3781
# Epoch 44/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3581 - loss: 1.3276 - val_accuracy: 0.3051 - val_loss: 1.3788
# Epoch 45/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3485 - loss: 1.3248 - val_accuracy: 0.3019 - val_loss: 1.3784
# Epoch 46/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3578 - loss: 1.3230 - val_accuracy: 0.3037 - val_loss: 1.3801
# Epoch 47/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3642 - loss: 1.3203 - val_accuracy: 0.3008 - val_loss: 1.3818
# Epoch 48/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3599 - loss: 1.3252 - val_accuracy: 0.3005 - val_loss: 1.3823
# Epoch 49/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3629 - loss: 1.3233 - val_accuracy: 0.2989 - val_loss: 1.3803
# Epoch 50/50
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3696 - loss: 1.3171 - val_accuracy: 0.2923 - val_loss: 1.3816

# %%
val_loss, val_acc = ffnn.evaluate(X_val, y_val, verbose=0)
test_loss, test_acc = ffnn.evaluate(X_test, y_test, verbose=0)

print("FFNN Validation Accuracy:", val_acc)
print("FFNN Test Accuracy:", test_acc)
# Out:
# FFNN Validation Accuracy: 0.2922666668891907
# FFNN Test Accuracy: 0.29973334074020386

# %%
results["FFNN (Multi-hot)"] = {
    "val_acc": float(val_acc),
    "test_acc": float(test_acc)
}

results
# Out:
# {'SVM (TF-IDF)': {'val_acc': 0.2850666666666667, 'test_acc': 0.2872},
#  'FFNN (Multi-hot)': {'val_acc': 0.2922666668891907,
#   'test_acc': 0.29973334074020386}}

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

X_seq = df["Symptom_Seq"].tolist()

X_train = pad_sequences([X_seq[i] for i in train_idx], maxlen=max_len)
X_val   = pad_sequences([X_seq[i] for i in val_idx],   maxlen=max_len)
X_test  = pad_sequences([X_seq[i] for i in test_idx],  maxlen=max_len)

y_train = y_cat[train_idx]
y_val   = y_cat[val_idx]
y_test  = y_cat[test_idx]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, Dropout

rnn = Sequential([
    Embedding(input_dim=len(symptoms), output_dim=16, input_length=max_len),
    SimpleRNN(32),
    Dropout(0.3),
    Dense(4, activation="softmax")
])

rnn.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

rnn.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history = rnn.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=256,
    verbose=1
)
# Out:
# Epoch 1/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.2904 - loss: 1.3715 - val_accuracy: 0.2928 - val_loss: 1.3615
# Epoch 2/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3052 - loss: 1.3619 - val_accuracy: 0.2933 - val_loss: 1.3613
# Epoch 3/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3008 - loss: 1.3631 - val_accuracy: 0.2893 - val_loss: 1.3615
# Epoch 4/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3162 - loss: 1.3576 - val_accuracy: 0.2936 - val_loss: 1.3622
# Epoch 5/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3122 - loss: 1.3588 - val_accuracy: 0.2899 - val_loss: 1.3625
# Epoch 6/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3118 - loss: 1.3561 - val_accuracy: 0.2899 - val_loss: 1.3631
# Epoch 7/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3128 - loss: 1.3590 - val_accuracy: 0.2880 - val_loss: 1.3633
# Epoch 8/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3217 - loss: 1.3537 - val_accuracy: 0.2904 - val_loss: 1.3637
# Epoch 9/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3207 - loss: 1.3566 - val_accuracy: 0.2920 - val_loss: 1.3646
# Epoch 10/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3181 - loss: 1.3578 - val_accuracy: 0.2976 - val_loss: 1.3656
# Epoch 11/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3242 - loss: 1.3545 - val_accuracy: 0.2955 - val_loss: 1.3648
# Epoch 12/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3197 - loss: 1.3530 - val_accuracy: 0.2923 - val_loss: 1.3668
# Epoch 13/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3203 - loss: 1.3528 - val_accuracy: 0.2957 - val_loss: 1.3662
# Epoch 14/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3193 - loss: 1.3518 - val_accuracy: 0.2923 - val_loss: 1.3661
# Epoch 15/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3328 - loss: 1.3516 - val_accuracy: 0.2920 - val_loss: 1.3667
# Epoch 16/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3153 - loss: 1.3547 - val_accuracy: 0.2944 - val_loss: 1.3671
# Epoch 17/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3235 - loss: 1.3509 - val_accuracy: 0.2928 - val_loss: 1.3672
# Epoch 18/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3243 - loss: 1.3513 - val_accuracy: 0.2939 - val_loss: 1.3675
# Epoch 19/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3237 - loss: 1.3514 - val_accuracy: 0.2933 - val_loss: 1.3673
# Epoch 20/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3294 - loss: 1.3503 - val_accuracy: 0.2917 - val_loss: 1.3671
# Epoch 21/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3315 - loss: 1.3487 - val_accuracy: 0.2947 - val_loss: 1.3674
# Epoch 22/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3253 - loss: 1.3501 - val_accuracy: 0.2899 - val_loss: 1.3682
# Epoch 23/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3185 - loss: 1.3517 - val_accuracy: 0.2915 - val_loss: 1.3678
# Epoch 24/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.3205 - loss: 1.3541 - val_accuracy: 0.2944 - val_loss: 1.3685
# Epoch 25/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3238 - loss: 1.3526 - val_accuracy: 0.2957 - val_loss: 1.3680
# Epoch 26/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3242 - loss: 1.3514 - val_accuracy: 0.2925 - val_loss: 1.3687
# Epoch 27/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3287 - loss: 1.3493 - val_accuracy: 0.2928 - val_loss: 1.3685
# Epoch 28/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3285 - loss: 1.3459 - val_accuracy: 0.2917 - val_loss: 1.3688
# Epoch 29/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3300 - loss: 1.3521 - val_accuracy: 0.2939 - val_loss: 1.3688
# Epoch 30/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.
100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3330 - loss: 1.3460 - val_accuracy: 0.2883 - val_loss: 1.3703
# Epoch 93/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3327 - loss: 1.3483 - val_accuracy: 0.2901 - val_loss: 1.3711
# Epoch 94/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3316 - loss: 1.3448 - val_accuracy: 0.2875 - val_loss: 1.3711
# Epoch 95/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3331 - loss: 1.3477 - val_accuracy: 0.2952 - val_loss: 1.3706
# Epoch 96/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3355 - loss: 1.3476 - val_accuracy: 0.2904 - val_loss: 1.3711
# Epoch 97/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3267 - loss: 1.3491 - val_accuracy: 0.2933 - val_loss: 1.3709
# Epoch 98/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3250 - loss: 1.3474 - val_accuracy: 0.2917 - val_loss: 1.3708
# Epoch 99/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3293 - loss: 1.3503 - val_accuracy: 0.2939 - val_loss: 1.3711
# Epoch 100/100
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3225 - loss: 1.3500 - val_accuracy: 0.2917 - val_loss: 1.3712

# %%
val_loss, val_acc = rnn.evaluate(X_val, y_val, verbose=0)
test_loss, test_acc = rnn.evaluate(X_test, y_test, verbose=0)

print("RNN Validation Accuracy:", val_acc)
print("RNN Test Accuracy:", test_acc)
# Out:
# RNN Validation Accuracy: 0.2917333245277405
# RNN Test Accuracy: 0.30533334612846375

# %%
results["RNN (Sequence)"] = {
    "val_acc": float(val_acc),
    "test_acc": float(test_acc)
}

results
# Out:
# {'SVM (TF-IDF)': {'val_acc': 0.2850666666666667, 'test_acc': 0.2872},
#  'FFNN (Multi-hot)': {'val_acc': 0.2922666668891907,
#   'test_acc': 0.29973334074020386},
#  'RNN (Sequence)': {'val_acc': 0.2917333245277405,
#   'test_acc': 0.30533334612846375}}

# %%
import tensorflow as tf
tf.keras.backend.clear_session()

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# Raw sequences
X_seq_all = df["Symptom_Seq"].tolist()

# Build splits
X_train = pad_sequences(
    [X_seq_all[i] for i in train_idx],
    maxlen=max_len,
    padding="post"
)

X_val = pad_sequences(
    [X_seq_all[i] for i in val_idx],
    maxlen=max_len,
    padding="post"
)

X_test = pad_sequences(
    [X_seq_all[i] for i in test_idx],
    maxlen=max_len,
    padding="post"
)

# Labels
y_train = y_cat[train_idx]
y_val   = y_cat[val_idx]
y_test  = y_cat[test_idx]

# %%
X_train = X_train.astype("int32")
X_val   = X_val.astype("int32")
X_test  = X_test.astype("int32")

y_train = y_train.astype("float32")
y_val   = y_val.astype("float32")
y_test  = y_test.astype("float32")

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_train dtype:", X_train.dtype)
print("Unique tokens in X_train:", np.unique(X_train[:5]))
# Out:
# X_train shape: (17500, 7)
# y_train shape: (17500, 4)
# X_train dtype: int32
# Unique tokens in X_train: [ 0  1  3  6  9 11 14 15 21 25 26 27]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout

lstm = Sequential()
lstm.add(
    Embedding(
        input_dim=len(symptoms),
        output_dim=16,
        input_length=max_len
    )
)
lstm.add(LSTM(32))
lstm.add(Dropout(0.3))
lstm.add(Dense(4, activation="softmax"))

lstm.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

lstm.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history = lstm.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=20,
    batch_size=128,
    verbose=1
)
# Out:
# Epoch 1/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.2925 - loss: 1.3696 - val_accuracy: 0.2963 - val_loss: 1.3613
# Epoch 2/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2971 - loss: 1.3627 - val_accuracy: 0.2987 - val_loss: 1.3617
# Epoch 3/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2951 - loss: 1.3606 - val_accuracy: 0.2984 - val_loss: 1.3612
# Epoch 4/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3074 - loss: 1.3603 - val_accuracy: 0.2968 - val_loss: 1.3606
# Epoch 5/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2997 - loss: 1.3609 - val_accuracy: 0.3016 - val_loss: 1.3607
# Epoch 6/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3098 - loss: 1.3566 - val_accuracy: 0.3059 - val_loss: 1.3612
# Epoch 7/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.3069 - loss: 1.3600 - val_accuracy: 0.3005 - val_loss: 1.3612
# Epoch 8/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3039 - loss: 1.3630 - val_accuracy: 0.3000 - val_loss: 1.3606
# Epoch 9/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3058 - loss: 1.3613 - val_accuracy: 0.3027 - val_loss: 1.3610
# Epoch 10/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.3027 - loss: 1.3605 - val_accuracy: 0.3008 - val_loss: 1.3610
# Epoch 11/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.3037 - loss: 1.3593 - val_accuracy: 0.3027 - val_loss: 1.3605
# Epoch 12/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3112 - loss: 1.3581 - val_accuracy: 0.2965 - val_loss: 1.3606
# Epoch 13/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3046 - loss: 1.3599 - val_accuracy: 0.2949 - val_loss: 1.3602
# Epoch 14/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3066 - loss: 1.3596 - val_accuracy: 0.2973 - val_loss: 1.3606
# Epoch 15/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3070 - loss: 1.3593 - val_accuracy: 0.2989 - val_loss: 1.3603
# Epoch 16/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3082 - loss: 1.3569 - val_accuracy: 0.3024 - val_loss: 1.3600
# Epoch 17/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3121 - loss: 1.3566 - val_accuracy: 0.2963 - val_loss: 1.3602
# Epoch 18/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3076 - loss: 1.3594 - val_accuracy: 0.2992 - val_loss: 1.3602
# Epoch 19/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.3111 - loss: 1.3588 - val_accuracy: 0.3003 - val_loss: 1.3601
# Epoch 20/20
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.3096 - loss: 1.3581 - val_accuracy: 0.2960 - val_loss: 1.3601

# %%
val_loss, val_acc = lstm.evaluate(X_val, y_val, verbose=0)
test_loss, test_acc = lstm.evaluate(X_test, y_test, verbose=0)

print("LSTM Validation Accuracy:", val_acc)
print("LSTM Test Accuracy:", test_acc)
# Out:
# LSTM Validation Accuracy: 0.29600000381469727
# LSTM Test Accuracy: 0.30880001187324524

# %%
results["LSTM (Sequence)"] = {
    "val_acc": float(val_acc),
    "test_acc": float(test_acc)
}

results
# Out:
# {'SVM (TF-IDF)': {'val_acc': 0.2850666666666667, 'test_acc': 0.2872},
#  'FFNN (Multi-hot)': {'val_acc': 0.2922666668891907,
#   'test_acc': 0.29973334074020386},
#  'RNN (Sequence)': {'val_acc': 0.2917333245277405,
#   'test_acc': 0.30533334612846375},
#  'LSTM (Sequence)': {'val_acc': 0.29600000381469727,
#   'test_acc': 0.30880001187324524}}

# %%
group_to_diseases = (
    df.groupby("Disease_Group")["Disease"]
      .unique()
      .apply(list)
      .to_dict()
)

group_to_diseases
# Out:
# {0: ['Allergy',
#   'Heart Disease',
#   'Dermatitis',
#   'Sinusitis',
#   "Parkinson's",
#   'Epilepsy',
#   'Tuberculosis',
#   'Common Cold',
#   'Chronic Kidney Disease'],
#  1: ['Food Poisoning',
#   'Arthritis',
#   'Dementia',
#   'Liver Disease',
#   'IBS',
#   'Migraine',
#   'Anxiety'],
#  2: ['Thyroid Disorder',
#   'Influenza',
#   'Stroke',
#   'Bronchitis',
#   'Asthma',
#   'Depression',
#   'Pneumonia',
#   'Ulcer',
#   'Hypertension'],
#  3: ['COVID-19', 'Diabetes', 'Obesity', 'Gastritis', 'Anemia']}

# %%
def predict_svm(symptom_text):
    X = tfidf.transform([symptom_text])
    group = int(svm.predict(X)[0])
    return group

# %%
def predict_ffnn(symptom_text):
    symptoms_input = [s.strip().lower() for s in symptom_text.split(",")]
    vec = np.zeros(len(symptoms), dtype=np.int32)
    for s in symptoms_input:
        if s in symptom_index:
            vec[symptom_index[s]] = 1

    probs = ffnn.predict(vec.reshape(1, -1), verbose=0)[0]
    return int(np.argmax(probs))

# %%
def predict_rnn(symptom_text):
    symptoms_input = [s.strip().lower() for s in symptom_text.split(",")]
    seq = [symptom_index[s] for s in symptoms_input if s in symptom_index]
    seq = pad_sequences([seq], maxlen=max_len, padding="post")
    seq = seq.astype("int32")

    probs = rnn.predict(seq, verbose=0)[0]
    return int(np.argmax(probs))

# %%
def predict_lstm(symptom_text):
    symptoms_input = [s.strip().lower() for s in symptom_text.split(",")]
    seq = [symptom_index[s] for s in symptoms_input if s in symptom_index]
    seq = pad_sequences([seq], maxlen=max_len, padding="post")
    seq = seq.astype("int32")

    probs = lstm.predict(seq, verbose=0)[0]
    return int(np.argmax(probs))

# %%
def demo_all_models(symptom_text):
    results = {}

    results["SVM (TF-IDF)"] = predict_svm(symptom_text)
    results["FFNN (Multi-hot)"] = predict_ffnn(symptom_text)
    results["RNN (Sequence)"] = predict_rnn(symptom_text)
    results["LSTM (Sequence)"] = predict_lstm(symptom_text)

    for model, group in results.items():
        print(f"\n{model}: Group {group}")
        print("Diseases:", ", ".join(group_to_diseases[group]))

# %%
demo_all_models("fever, cough, fatigue")
# Out:
# SVM (TF-IDF): Group 0
# Diseases: Allergy, Heart Disease, Dermatitis, Sinusitis, Parkinson's, Epilepsy, Tuberculosis, Common Cold, Chronic Kidney Disease
#
# FFNN (Multi-hot): Group 0
# Diseases: Allergy, Heart Disease, Dermatitis, Sinusitis, Parkinson's, Epilepsy, Tuberculosis, Common Cold, Chronic Kidney Disease
#
# RNN (Sequence): Group 0
# Diseases: Allergy, Heart Disease, Dermatitis, Sinusitis, Parkinson's, Epilepsy, Tuberculosis, Common Cold, Chronic Kidney Disease
#
# LSTM (Sequence): Group 0
# Diseases: Allergy, Heart Disease, Dermatitis, Sinusitis, Parkinson's, Epilepsy, Tuberculosis, Common Cold, Chronic Kidney Disease
